# %% [markdown]
# ## 1. Student Performance

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(42)

# %%
df = pd.DataFrame({
    "student_id": range(1, 501),
    "study_hours": np.random.randint(1, 10, 500),
    "attendance": np.random.randint(50, 100, 500),
    "exam_score": np.random.randint(30, 100, 500)
})

# %% [markdown]
# #### Basic inspection
# ----

# %%
df.head()
# Out:
#    student_id  study_hours  attendance  exam_score
# 0           1            7          80          37
# 1           2            4          68          34
# 2           3            8          93          58
# 3           4            5          88          76
# 4           5            7          76          97

# %%
df.tail()
# Out:
#      student_id  study_hours  attendance  exam_score
# 495         496            7          85          85
# 496         497            9          94          50
# 497         498            4          73          76
# 498         499            4          64          88
# 499         500            6          78          35

# %%
df.sample(5)
# Out:
#      student_id  study_hours  attendance  exam_score
# 56           57            2          81          70
# 418         419            7          61          71
# 494         495            1          96          96
# 217         218            3          52          83
# 290         291            9          66          44

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   500 non-null    int64
#  1   study_hours  500 non-null    int64
#  2   attendance   500 non-null    int64
#  3   exam_score   500 non-null    int64
# dtypes: int64(4)
# memory usage: 15.8 KB

# %% [markdown]
# #### Feature engineering
# ---

# %%
df["performance"] = pd.cut(
    df["exam_score"],
    bins=[0, 50, 75, 100],
    labels=["Low", "Medium", "High"] 
)
df
# Out:
#      student_id  study_hours  attendance  exam_score performance
# 0             1            7          80          37         Low
# 1             2            4          68          34         Low
# 2             3            8          93          58      Medium
# 3             4            5          88          76        High
# 4             5            7          76          97        High
# ..          ...          ...         ...         ...         ...
# 495         496            7          85          85        High
# 496         497            9          94          50         Low
# 497         498            4          73          76        High
# 498         499            4          64          88        High
# 499         500            6          78          35         Low
#
# [500 rows x 5 columns]

# %% [markdown]
# #### Statistical analysis
# ---

# %%
df.describe()
# Out:
#        student_id  study_hours  attendance  exam_score
# count  500.000000   500.000000  500.000000  500.000000
# mean   250.500000     4.906000   73.926000   64.308000
# std    144.481833     2.612051   14.456227   19.808733
# min      1.000000     1.000000   50.000000   30.000000
# 25%    125.750000     3.000000   61.000000   47.000000
# 50%    250.500000     5.000000   75.000000   65.000000
# 75%    375.250000     7.000000   86.000000   82.000000
# max    500.000000     9.000000   99.000000   99.000000

# %%
df[['study_hours','attendance','exam_score']].mean()
# Out:
# study_hours     4.906
# attendance     73.926
# exam_score     64.308
# dtype: float64

# %% [markdown]
# #### Group analysis
# ----

# %%
df.groupby("performance")["exam_score"].agg(["mean","min","max","count"])
# Out:
#                   mean  min  max  count
# performance
# Low          39.958904   30   50    146
# Medium       62.881720   51   75    186
# High         87.047619   76   99    168

# %% [markdown]
# #### Filtering
# ---

# %%
high_performers = df[(df["study_hours"] > 6) & (df["attendance"] > 80)]
high_performers
# Out:
#      student_id  study_hours  attendance  exam_score performance
# 2             3            8          93          58      Medium
# 10           11            8          94          55      Medium
# 25           26            7          82          72      Medium
# 31           32            7          94          80        High
# 37           38            9          86          30         Low
# ..          ...          ...         ...         ...         ...
# 481         482            7          86          75      Medium
# 483         484            9          82          33         Low
# 490         491            8          82          31         Low
# 495         496            7          85          85        High
# 496         497            9          94          50         Low
#
# [66 rows x 5 columns]

# %% [markdown]
# #### Sorting
# ---

# %%
df.sort_values("exam_score", ascending=False).head(10)
# Out:
#      student_id  study_hours  attendance  exam_score performance
# 255         256            3          85          99        High
# 72           73            9          90          99        High
# 393         394            7          51          99        High
# 179         180            2          76          99        High
# 447         448            1          89          99        High
# 340         341            3          80          99        High
# 152         153            3          52          98        High
# 398         399            2          50          98        High
# 221         222            8          78          98        High
# 13           14            6          77          98        High

# %% [markdown]
# #### Correlation
# ___

# %%
df.corr(numeric_only=True)
# Out:
#              student_id  study_hours  attendance  exam_score
# student_id     1.000000    -0.047810   -0.017097    0.028112
# study_hours   -0.047810     1.000000    0.046094   -0.005830
# attendance    -0.017097     0.046094    1.000000   -0.042155
# exam_score     0.028112    -0.005830   -0.042155    1.000000

# %% [markdown]
# ### *Visualization (Matplotlib + Seaborn)*
# ----

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Pairplot
# ---

# %%
sns.pairplot(df[["study_hours", "attendance", "exam_score"]])
plt.show()

# %% [markdown]
# #### Heatmap
# ---

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# #### Boxplot
# ----

# %%
sns.boxplot(x="performance", y="exam_score", data=df)
plt.title("Exam Score by Performance Category")
plt.show()

# %% [markdown]
# #### Line plot (sorted)
# ---

# %%
df_sorted = df.sort_values("study_hours")
plt.plot(df_sorted["study_hours"], df_sorted["exam_score"])
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title("Study Hours Trend")
plt.show()

# %% [markdown]
# -----
# -----
# ## 2. Employee Analytics

# %% [markdown]
# #### Dataset Creation
# ---

# %%
np.random.seed(10)

# %%
df = pd.DataFrame({
    "employee_id": range(1, 501),
    "experience_years": np.random.randint(0, 20, 500),
    "salary": np.random.randint(20000, 150000, 500),
    "performance_rating": np.random.randint(1, 6, 500),
    "department": np.random.choice(["IT", "HR", "Sales", "Finance"], 500)
})

# %% [markdown]
# #### Inspection
# ---

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         500 non-null    int64
#  1   experience_years    500 non-null    int64
#  2   salary              500 non-null    int64
#  3   performance_rating  500 non-null    int64
#  4   department          500 non-null    str
# dtypes: int64(4), str(1)
# memory usage: 19.7 KB

# %%
df.describe(include="all")
# Out:
#         employee_id  experience_years         salary  performance_rating  \
# count    500.000000        500.000000     500.000000           500.00000
# unique          NaN               NaN            NaN                 NaN
# top             NaN               NaN            NaN                 NaN
# freq            NaN               NaN            NaN                 NaN
# mean     250.500000          9.576000   85823.474000             3.14200
# std      144.481833          5.811348   37365.391537             1.43176
# min        1.000000          0.000000   20439.000000             1.00000
# 25%      125.750000          4.000000   53830.750000             2.00000
# 50%      250.500000         10.000000   82455.500000             3.00000
# 75%      375.250000         14.000000  118756.250000             4.00000
# max      500.000000         19.000000  149980.000000             5.00000
#
#        department
# count         500
# unique          4
# top       Finance
# freq          134
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %% [markdown]
# #### GroupBy with multiple columns
# ---

# %%
df.groupby("department")["salary"].agg(["mean", "median", "max"])
# Out:
#                     mean   median     max
# department
# Finance     81503.716418  75362.0  148364
# HR          90679.735537  92929.0  149683
# IT          85321.067797  81965.0  149586
# Sales       86221.299213  80565.0  149980

# %% [markdown]
# #### Pivot table
# ----

# %%
pd.pivot_table(
    df,
    values="salary",
    index="department",
    columns="performance_rating",
    aggfunc="mean"
)
# Pivot table that shows the average salary for each department, split by performance rating
# Out:
# performance_rating              1             2             3             4  \
# department
# Finance              81104.160000  85037.458333  82488.243243  70636.880000
# HR                  100359.392857  91616.900000  87315.411765  87145.333333
# IT                   87228.222222  87855.304348  91206.454545  78431.142857
# Sales                97974.250000  89322.533333  88520.095238  78749.807692
#
# performance_rating             5
# department
# Finance             88478.608696
# HR                  86062.406250
# IT                  83044.411765
# Sales               82247.764706

# %% [markdown]
# #### Ranking
# ---

# %%
df["salary_rank"] = df["salary"].rank(ascending=False)
df
# Out:
#      employee_id  experience_years  salary  performance_rating department  \
# 0              1                 9  122555                   2      Sales
# 1              2                12  118327                   4    Finance
# 2              3                 2   50855                   3    Finance
# 3              4                 1   89117                   2         IT
# 4              5                 2  113951                   4    Finance
# ..           ...               ...     ...                 ...        ...
# 495          496                17   77582                   4      Sales
# 496          497                13   76960                   1         HR
# 497          498                 2  104122                   3         HR
# 498          499                19   43251                   1         IT
# 499          500                 3  140401                   3         IT
#
#      salary_rank
# 0          111.0
# 1          127.0
# 2          389.0
# 3          235.0
# 4          149.0
# ..           ...
# 495        278.0
# 496        279.0
# 497        184.0
# 498        421.0
# 499         37.0
#
# [500 rows x 6 columns]

# %%
df["level"] = np.where(df["experience_years"] >= 10, "Senior", "Junior")
df
# Out:
#      employee_id  experience_years  salary  performance_rating department  \
# 0              1                 9  122555                   2      Sales
# 1              2                12  118327                   4    Finance
# 2              3                 2   50855                   3    Finance
# 3              4                 1   89117                   2         IT
# 4              5                 2  113951                   4    Finance
# ..           ...               ...     ...                 ...        ...
# 495          496                17   77582                   4      Sales
# 496          497                13   76960                   1         HR
# 497          498                 2  104122                   3         HR
# 498          499                19   43251                   1         IT
# 499          500                 3  140401                   3         IT
#
#      salary_rank   level
# 0          111.0  Junior
# 1          127.0  Senior
# 2          389.0  Junior
# 3          235.0  Junior
# 4          149.0  Junior
# ..           ...     ...
# 495        278.0  Senior
# 496        279.0  Senior
# 497        184.0  Junior
# 498        421.0  Senior
# 499         37.0  Junior
#
# [500 rows x 7 columns]

# %% [markdown]
# #### Value counts
# ---

# %%
df["department"].value_counts(normalize=True)
# Out:
# department
# Finance    0.268
# Sales      0.254
# HR         0.242
# IT         0.236
# Name: proportion, dtype: float64

# %% [markdown]
# ### *Visualization*
# ----

# %% [markdown]
# #### Salary distribution

# %%
sns.histplot(df["salary"], kde=True)
plt.title("Salary Distribution")
plt.show()

# %% [markdown]
# #### Experience vs Salary

# %%
sns.scatterplot(x="experience_years", y="salary", hue="department", data=df)
plt.title("Experience vs Salary by Department")
plt.show()

# %% [markdown]
# #### Bar plot

# %%
sns.barplot(x="department", y="salary", data=df)
plt.title("Average Salary by Department")
plt.show()

# %% [markdown]
# #### Boxplot

# %%
sns.boxplot(x="department", y="salary", data=df)
plt.title("Salary Spread by Department")
plt.show()
