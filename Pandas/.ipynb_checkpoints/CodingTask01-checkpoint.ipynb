# %% [markdown]
# #### 1. Create DataFrame

# %%
import pandas as pd
data ={
    "Name" : ["Alice","Bob","Charlie"],
    "Age" : [22,24,23],
    "Marks" : [85,90,88] 
    }
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Marks
# 0    Alice   22     85
# 1      Bob   24     90
# 2  Charlie   23     88

# %% [markdown]
# ----
# #### 2. Read CSV

# %%
df.to_csv("data.csv", index=False)
df1=pd.read_csv("data.csv")
print(dataset.head())
# Out:
#       Name  Age  Marks
# 0    Alice   22     85
# 1      Bob   24     90
# 2  Charlie   23     88

# %% [markdown]
# ----
# #### 3.Basic Operations

# %%
print(df1['Age'].mean())
print(df1["Marks"].max())
# Out:
# 23.0
# 90

# %%
print(df1[df1['Marks'] > 85])
# Out:
#       Name  Age  Marks
# 1      Bob   24     90
# 2  Charlie   23     88
